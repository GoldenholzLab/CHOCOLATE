# %%
#Lparams = [0.30981,7.7939,4.8068,0.62574,1.1151,8.3405]
#Lparams= [1.2733,5.6446,3.4521,4.864,-0.1054,12.873]
#Lparams = [0.15044,0.9999,0.24119,0.0,0.011649,0.92924,0.050595,0.0,0.017547,0.0026228]
#Lparams = [1.2733,5.6446,3.4521,4.864,-0.1054,12.873]
### FOR samprate24:
# Lparams = [2.2249,15.54,8.8178,4.7,-0.065587,0.28393]
## FOR sampRATE=1
#Lparams = [2.083,15.893,8.9197,4.3478,-0.2809,0.73516]
#Lparams = [1.9672,15.616,8.9173,3.8982,-0.26137,0.83451]
#Lparams = [2.358,15.084,9.6779,4.5411,-0.28041,0.93061]
#Lparams = [1.8502,15.995,9.7759,4.5473,-0.28714,0.7735]
#Lparams  = [2.1447,16.309,9.7793,4.6561,-0.28565,0.68398]
#Lparams = [1.9836,16.433,9.7213,4.6211,-0.26361,0.63607]
#Lparams = [2.2805,16.364,9.8807,4.6349,-0.26809,0.87806]
#Lparams = [2.4481,16.819,9.8818,5.1849,-0.31477,1.985]
#Lparams = [2.2804,17.309,10.271,5.3229,-0.29711,1.3145]
#Lparams = [1.8818,17.143,9.8771,5.2799,-0.2976,1.1716]
#Lparams = [1.6216,17.262,10.342,5.5982,-0.30353,1.2773]
Lparams = [1.5475,17.645,10.617,5.9917,-0.3085,1.5371]

# %%
# this code will draw the multicycle data from 1000 fake patients

#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import tryCombo5
periods,PLVs,permuteTest = tryCombo5(1000,Lparams=Lparams,fname='Fig4-cycles.eps')
# Out:
# patient:   0%|          | 0/1000 [00:00<?, ?it/s]
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in cdouble_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import make_basic_plots_3
make_basic_plots_3(REPS=50000,Lparams=Lparams,sampRATE=24)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import make_basic_plots_3
make_basic_plots_3(REPS=100000,Lparams=Lparams,sampRATE=1,fname='Fig3-basics.eps')
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %%
# show thet we have a max szs
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import show_histo
show_histo(theSize=150,sampRATE=1,repeats = 50000, lab='day',Lparams=Lparams)
show_histo(theSize=10,sampRATE=24,repeats = 10000, lab='hour',Lparams=Lparams)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/danielgoldenholz/Documents/GitHub/cycleSim/prove_realsim.py:889: RuntimeWarning: divide by zero encountered in log10
#   number_of_days = 365
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ...

# %%
# build a cratio plot vs sz freq, cratio = clusters / (isolated + clusters)
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import drawCratios,clusterTest1v2,defOverallcratios
clusterP = [.5, 1, 7, 1, 1]
drawCratios(repeats=1000,Lparams=Lparams, clusterParams=clusterP)
#drawCratios(repeats=10,Lparams=Lparams, clusterParams=clusterP)

clusterTest1v2(repeats=10000,Lparams=Lparams,clustP=clusterP)

defOverallcratios(repeats=10000,Lparams=Lparams,clusterParams=clusterP,theCUTOFF=45)
# Out:
# ...
# clustTest1:   0%|          | 0/10000 [00:00<?, ?it/s]
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# clustTest1:   0%|          | 0/10000 [00:00<?, ?it/s]
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import drawCratios,clusterTest1v2,defOverallcratios
clusterP = [.5, 1, 7, 1, 1]
#drawCratios(repeats=1000,Lparams=Lparams, clusterParams=clusterP)
#drawCratios(repeats=10,Lparams=Lparams, clusterParams=clusterP)

clusterTest1v2(repeats=10000,Lparams=Lparams,clustP=clusterP)
# Out:
# clustTest1:   0%|          | 0/10000 [00:00<?, ?it/s]
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# clustTest1:   0%|          | 0/10000 [00:00<?, ?it/s]
# With
# [80.46511627906978 19.53488372093023]
# Without
# [83.3009708737864 16.699029126213592]

# %%
# build a cratio plot vs sz freq, cratio = clusters / (isolated + clusters)
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import drawCratios,clusterTest1v2,defOverallcratios
clusterP = [.5, 1, 7, 1, 1]
#drawCratios(repeats=1000,Lparams=Lparams, clusterParams=clusterP)
#drawCratios(repeats=10,Lparams=Lparams, clusterParams=clusterP)

#clusterTest1v2(repeats=10000,Lparams=Lparams,clustP=clusterP)

defOverallcratios(repeats=10000,Lparams=Lparams,clusterParams=clusterP,theCUTOFF=15)
defOverallcratios(repeats=10000,Lparams=Lparams,clusterParams=clusterP,theCUTOFF=20)
defOverallcratios(repeats=10000,Lparams=Lparams,clusterParams=clusterP,theCUTOFF=25)
# Out:
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %%
#%load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import make_example
make_example(sampFREQ=24,howmanydays=300,byHowMuch=24*30,Lparams=Lparams)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/danielgoldenholz/Documents/GitHub/cycleSim/for_the_paper.ipynb Cell 8' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/danielgoldenholz/Documents/GitHub/cycleSim/for_the_paper.ipynb#ch0000005?line=2'>3</a> get_ipython().run_line_magic('autoreload', '2')
#       <a href='vscode-notebook-cell:/Users/danielgoldenholz/Documents/GitHub/cycleSim/for_the_paper.ipynb#ch0000005?line=3'>4</a> from prove_realsim import make_example
# ----> <a href='vscode-notebook-cell:/Users/danielgoldenholz/Documents/GitHub/cycleSim/for_the_paper.ipynb#ch0000005?line=4'>5</a> make_example(sampFREQ=24,howmanydays=300,byHowMuch=24*30,Lparams=Lparams)
#
# File ~/Documents/GitHub/cycleSim/prove_realsim.py:117, in make_example(sampFREQ, howmanydays, byHowMuch, Lparams)
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
from trialSimulator import runSet
X = runSet(100,Lparams=Lparams,minSz=8,N=200,DRG=.3,PCB=0,baseline=56,test=84)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/danielgoldenholz/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
from trialSimulator import runSet
X = runSet(10000,Lparams=Lparams,minSz=8,N=200,DRG=.3,PCB=0,baseline=56,test=84)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# /Users/dgodenh/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/dgodenh/miniforge3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %%
import numpy as np
print(np.mean(X,axis=0))
print(np.std(X,axis=0))
# Out:
# [17.74       39.74       14.00819709 41.10811226]
# [3.93857842 5.48018248 6.18966762 4.1844047 ]

# %%
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import draw_chocolate
draw_chocolate(Lparams)

# %%
np.linspace(100,500,17)
# Out:
# array([100., 125., 150., 175., 200., 225., 250., 275., 300., 325., 350.,
#        375., 400., 425., 450., 475., 500.])
