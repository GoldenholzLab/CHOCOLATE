# %%
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import make_basic_plots
make_basic_plots(REPS=10000,cyclesTF=True,clustersTF=True,maxlimitsTF=True)
make_basic_plots(REPS=10000,cyclesTF=True,clustersTF=False,maxlimitsTF=True)
make_basic_plots(REPS=10000,cyclesTF=False,clustersTF=False,maxlimitsTF=True)
make_basic_plots(REPS=10000,cyclesTF=True,clustersTF=True,maxlimitsTF=False)
# Out:
# Getting started....
# 100%|██████████| 10000/10000 [53:27<00:00,  3.12it/s]
# Getting started....
# 100%|██████████| 10000/10000 [15:27<00:00, 10.79it/s]
# Getting started....
# 100%|██████████| 10000/10000 [12:57<00:00, 12.86it/s]
# Getting started....
# 100%|██████████| 10000/10000 [51:50<00:00,  3.21it/s]

# %% [markdown]
# Adding clusters and cycles degraded things.

# %%
# %reload_ext autoreload
# %autoreload 2
from prove_realsim import make_basic_plots
R = 1000
make_basic_plots(REPS=R,cyclesTF=True,clustersTF=True,maxlimitsTF=False)
make_basic_plots(REPS=R,cyclesTF=True,clustersTF=True,maxlimitsTF=True)
# Out:
# R=1000, cycles=True clusters=True maxLim=False
# Getting started....
# 100%|██████████| 1000/1000 [05:23<00:00,  3.09it/s]
# R=1000, cycles=True clusters=True maxLim=True
# Getting started....
# 100%|██████████| 1000/1000 [05:14<00:00,  3.18it/s]

# %% [markdown]
# Turning off clusters did not help! Oh no. Maybe it was the high number limit thing. I'll turn off cycles too:

# %%
make_basic_plots(REPS=1000,cyclesTF=False,clustersTF=False)
# Out:
# Getting started....
# 100%|██████████| 1000/1000 [06:04<00:00,  2.74it/s]

# %% [markdown]
# The above will be re-run with the max seizure limits commented out.

# %%
make_basic_plots(REPS=1000,cyclesTF=False,clustersTF=False)
# Out:
# Getting started....
# 100%|██████████| 1000/1000 [06:05<00:00,  2.74it/s]
